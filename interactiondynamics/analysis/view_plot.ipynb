# %%
from IPython.display import Image, display
import os

plot_dir = "/home/akapociu/ift/interactiondynamics/plots/interaction_predictions"

for dirs in os.listdir(plot_dir):
    for filenames in os.listdir(plot_dir):
        full_path = os.path.join(plot_dir, filenames)
        display(Image(filename=full_path))
