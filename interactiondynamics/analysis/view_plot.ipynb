# %%
from IPython.display import Image, display
import os

plot_dir = "/home/akapociu/ift/interactiondynamics/plots/interaction_predictions/wave"

for filenames in os.listdir(plot_dir):
    full_path = os.path.join(plot_dir, filenames)
    display(Image(filename=full_path))

# %%
plot_dir = "/home/akapociu/ift/interactiondynamics/plots/interaction_predictions_clean"

for dirname in os.listdir(plot_dir):
    subdir = os.path.join(plot_dir, dirname)

    for filename in os.listdir(subdir):
        full_path = os.path.join(subdir, filename)
        display(Image(filename=full_path))
